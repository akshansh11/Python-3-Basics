# %% [markdown]
# ## **Lesson 5**
#
# ![turtle.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Our First Turtle Program**

# %%
import turtle #allows us to use the turtle library
wn=turtle.Screen() #creates a graphics window
akki=turtle.Turtle() #create a turtle named akki
akki.forward(170)
akki.left(90)
akki.forward(87)
