# %% [markdown]
# ## **Lecture 1**
# ![pylec1.png](data:image/png;base64,...)

# %% [markdown]
# # **Values and Data Types**
#
# The program manipulates the value in both numbers and word format. When any number or word is directly entered without assigning it to any variable then it is called literals. For example see the below code:

# %%
5
# Out:
# 5

# %%
"Hello, Sherlock!"
# Out:
# 'Hello, Sherlock!'

# %% [markdown]
# # **Operators and Operands**
#
# Expression can be thought of as a building block which can be combined to form large and more complicated expressions. The expression can be combined with the help of Operators. For example look below code:

# %%
print(450+150)
# Out:
# 600

# %%
print(670-641
      )
# Out:
# 29

# %%
print(35/3)
# Out:
# 11.666666666666666

# %% [markdown]
# In order to get only quotient in division process use below code:

# %%
print(24//5
      )
# Out:
# 4

# %% [markdown]
# In order to get the remainder only by division process follow below syntax code:

# %%
print(24%5)
# Out:
# 4

# %% [markdown]
# In ordet to get the exponent of any term use below code:

# %%
print(24**5)
# Out:
# 7962624

# %% [markdown]
# Python programming follows below operation sequence:
# 1. Parantheses
# 2. Exponential
# 3. Multiplication and Division
# 4. Addition and Subtraction
#
# Suppose we have to calculate the average of 20 and 30. Just look below code and observe:

# %%
print(20+30/2)
# Out:
# 35.0

# %% [markdown]
# So from above code we can see that we are not getting the output we want. So we have follow the sequences and operation which guides the python interpreter to result in accurate output.

# %%
print((20+30)/2)
# Out:
# 25.0
